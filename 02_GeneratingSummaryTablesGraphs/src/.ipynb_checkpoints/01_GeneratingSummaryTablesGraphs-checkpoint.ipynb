# %% [markdown]
#  # Analysis of Transportation Network Companies (TNCs) and Taxis in Chicago
#  ## Generating summary tables and graphs of the data
#  This notebook generates summary tables and graphs from the selected Taxi and TNC data for Chicago. The starting datasets for this notebook were generated by selecting one week of trips for each dataset: for the TNCs the selected week is November 5 - November 11, 2019; for the taxi trips, the selected week is November 7 - November 13, 2016.
#
#  A project by:<br><br>
#  Juan Francisco Saldarriaga<br>
#  Senior Data and Design Researcher<br>
#  Brown Institute for Media Innovation<br>
#  School of Journalism, Columbia University<br>
#  jfs2118@columbia.edu<br>
#  <br>
#  and<br><br>
#  David King<br>
#  School of Geographical Sciences and Urban Planning<br>
#  Faculty Advisor, Barrett Honors College<br>
#  Arizona State University<br>
#  david.a.king@asu.edu<br>
#
#  The original data for this project can be found at:
#  * Taxi trips: [Chicago Data Portal](https://data.cityofchicago.org/Transportation/Taxi-Trips/wrvz-psew), accessed on June 12, 2019.
#  * TNC trips: [Chicago Data Portal](https://data.cityofchicago.org/Transportation/Transportation-Network-Providers-Trips/m6dm-c72p), accessed on April 26, 2019.

# %% [markdown]
# ### Importing libraries (Pandas, Numpy, Geopandas, Matplotlib, and Shapely)

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
# %matplotlib inline

# %% [markdown]
# ### Setting global paths and filenames

# %%
inputDataPath = '../input/'
outputDataPath = '../output/'
tncInputFileName = 'SelectedTNC_Trips_181105_181111.csv'
taxiInputFileName = 'SelectedTaxi_Trips_161107_161113.csv'
tncOutputFileName = 'SelectedTNC_Trips_181105_181111_Datetime.csv'
taxiOutputFileName = 'SelectedTaxi_Trips_161107_161113_Datetime.csv'

# %% [markdown]
# ### Loading and exploring TNC data

# %%
tncData = pd.tncData = pd.read_csv(inputDataPath + tncInputFileName, delimiter=',', index_col=0)
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
tncData.head()
# Out:
#                                        Trip ID    Trip Start Timestamp  \
# 1038  0000093625f90e660c8275040a7f57e335ae147b  11/10/2018 10:45:00 AM
# 1039  00000988893ef92c0d44374d79aef52631cb7087  11/11/2018 01:15:00 AM
# 1041  0008f2d890c585c0729178d46bd0352ea8428b9a  11/07/2018 04:30:00 PM
# 1045  00131a71fdd0237dd323903986622464410f0200  11/07/2018 06:30:00 AM
# 1048  00164c1eb30516cbd645e04d044678b4e9f31bd2  11/06/2018 02:00:00 AM
#
#           Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 1038  11/10/2018 10:45:00 AM         314.0         1.2         1.703106e+10
# 1039  11/11/2018 01:15:00 AM         105.0         0.7         1.703183e+10
# 1041  11/07/2018 04:45:00 PM        1209.0         7.4                  NaN
# 1045  11/07/2018 07:00:00 AM        1914.0        19.7                  NaN
# 1048  11/06/2018 02:15:00 AM         434.0         1.7                  NaN
#
#       Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  \
# ...

# %%
tncData.tail()
# Out:
#                                            Trip ID    Trip Start Timestamp  \
# 17431970  fffe6e97132e6c727c0702fb37febabf9dd6bfec  11/06/2018 09:00:00 PM
# 17431994  ffff620bb8413cd21ecda2c007860db177ce260d  11/09/2018 08:00:00 PM
# 17431999  ffffb0b495c0894f0f10333fc418454dee21fc13  11/08/2018 09:15:00 AM
# 17432000  ffffb4b4c7c835bcb2ebc46f46a2a0e45bc36be9  11/10/2018 11:45:00 PM
# 17432010  fffffd66c52c5e40d1f2eed1fbf8aabcc61c39a0  11/11/2018 08:45:00 AM
#
#               Trip End Timestamp  Trip Seconds  Trip Miles  \
# 17431970  11/06/2018 09:00:00 PM          57.0         0.3
# 17431994  11/09/2018 08:30:00 PM        1031.0         4.4
# 17431999  11/08/2018 09:45:00 AM        1848.0        12.0
# 17432000  11/11/2018 12:15:00 AM        2141.0        15.0
# 17432010  11/11/2018 09:15:00 AM        1000.0         9.0
#
#           Pickup Census Tract  Dropoff Census Tract  Pickup Community Area  \
# 17431970                  NaN                   NaN                   28.0
# ...

# %%
tncData.shape
# Out:
# (2140207, 21)

# %%
tncData.dtypes
# Out:
# Trip ID                        object
# Trip Start Timestamp           object
# Trip End Timestamp             object
# Trip Seconds                  float64
# Trip Miles                    float64
# Pickup Census Tract           float64
# Dropoff Census Tract          float64
# Pickup Community Area         float64
# Dropoff Community Area        float64
# Fare                          float64
# Tip                             int64
# Additional Charges            float64
# Trip Total                    float64
# Shared Trip Authorized           bool
# Trips Pooled                    int64
# Pickup Centroid Latitude      float64
# Pickup Centroid Longitude     float64
# Pickup Centroid Location       object
# Dropoff Centroid Latitude     float64
# Dropoff Centroid Longitude    float64
# Dropoff Centroid Location      object
# dtype: object

# %% [markdown]
# ### Creating new fields of type `datetime` for start and end times

# %%
# Transform fields to 'Datetime'
tncData['StartDateTime'] = pd.to_datetime(tncData['Trip Start Timestamp'])
tncData['EndDateTime'] = pd.to_datetime(tncData['Trip End Timestamp'])

# %%
tncData.dtypes
# Out:
# Trip ID                               object
# Trip Start Timestamp                  object
# Trip End Timestamp                    object
# Trip Seconds                         float64
# Trip Miles                           float64
# Pickup Census Tract                  float64
# Dropoff Census Tract                 float64
# Pickup Community Area                float64
# Dropoff Community Area               float64
# Fare                                 float64
# Tip                                    int64
# Additional Charges                   float64
# Trip Total                           float64
# Shared Trip Authorized                  bool
# Trips Pooled                           int64
# Pickup Centroid Latitude             float64
# Pickup Centroid Longitude            float64
# Pickup Centroid Location              object
# Dropoff Centroid Latitude            float64
# Dropoff Centroid Longitude           float64
# Dropoff Centroid Location             object
# ...

# %% [markdown]
# ### Generating summary statistics for TNC trips

# %%
totalTNCRides = len(tncData)
print('Total TNC rides:', totalTNCRides)
# Out:
# Total TNC rides: 2140207

# %% [markdown]
# **Fares**

# %%
tncAvgFare = tncData['Fare'].mean()
tncMaxFare = tncData['Fare'].max()
tncMinFare = tncData['Fare'].min()
print('Average TNC fare:', tncAvgFare)
print('Maximum TNC fare:', tncMaxFare)
print('Minimum TNC fare:', tncMinFare)
print('Fare 25th quantile:', tncData['Fare'].quantile(.25))
print('Fare 50th quantile:', tncData['Fare'].quantile(.5))
print('Fare 75th quantile:', tncData['Fare'].quantile(.75))
# Out:
# Average TNC fare: 11.103463356581864
# Maximum TNC fare: 1090.0
# Minimum TNC fare: 0.0
# Fare 25th quantile: 5.0
# Fare 50th quantile: 7.5
# Fare 75th quantile: 12.5

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncData['Fare'], vert=False)
ax1.title.set_text('TNC Fare Boxplot')

# %% [markdown]
# Removing top 2% of fares

# %%
tncFare98 = tncData[tncData['Fare'] <= tncData['Fare'].quantile(.98)]
tncAvgFare = tncFare98['Fare'].mean()
tncMaxFare = tncFare98['Fare'].max()
tncMinFare = tncFare98['Fare'].min()
print('Average TNC fare:', tncAvgFare)
print('Maximum TNC fare:', tncMaxFare)
print('Minimum TNC fare:', tncMinFare)
# Out:
# Average TNC fare: 10.356004465442012
# Maximum TNC fare: 40.0
# Minimum TNC fare: 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncFare98['Fare'], vert=False)
ax1.title.set_text('TNC Fare (98th percentile) Boxplot')

# %% [markdown]
# **Tips**

# %%
tncAvgTip = tncData['Tip'].mean()
tncMaxTip = tncData['Tip'].max()
tncMinTip = tncData['Tip'].min()
print('Average TNC tip:', tncAvgTip)
print('Maximum TNC tip:', tncMaxTip)
print('Minimum TNC tip:', tncMinTip)
print('Tip 25th quantile:', tncData['Tip'].quantile(.25))
print('Tip 50th quantile:', tncData['Tip'].quantile(.5))
print('Tip 75th quantile:', tncData['Tip'].quantile(.75))
# Out:
# Average TNC tip: 0.5519667022862742
# Maximum TNC tip: 100
# Minimum TNC tip: 0
# Tip 25th quantile: 0.0
# Tip 50th quantile: 0.0
# Tip 75th quantile: 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncData['Tip'], vert=False)
ax1.title.set_text('TNC Tip Boxplot')

# %% [markdown]
# Removing top 2% of tips

# %%
tncTip98 = tncData[tncData['Tip'] <= tncData['Tip'].quantile(.98)]
tncAvgTip = tncTip98['Tip'].mean()
tncMaxTip = tncTip98['Tip'].max()
tncMinTip = tncTip98['Tip'].min()
print('Average TNC tip:', tncAvgTip)
print('Maximum TNC tip:', tncMaxTip)
print('Minimum TNC tip:', tncMinTip)
# Out:
# Average TNC tip: 0.4221806609537837
# Maximum TNC tip: 5
# Minimum TNC tip: 0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncTip98['Tip'], vert=False)
ax1.title.set_text('TNC Tip (98th percentile) Boxplot')

# %% [markdown]
# **Total Fares (Fare + Tip)**

# %%
tncAvgTripTotal = tncData['Trip Total'].mean()
tncMaxTripTotal = tncData['Trip Total'].max()
tncMinTripTotal = tncData['Trip Total'].min()
print('Average TNC trip total fare (fare + tip):', tncAvgTripTotal)
print('Maximum TNC trip total fare (fare + tip):', tncMaxTripTotal)
print('Minimum TNC trip total fare (fare + tip):', tncMinTripTotal)
print('Total fare (fare + tip) 25th quantile:', tncData['Trip Total'].quantile(.25))
print('Total fare (fare + tip) 50th quantile:', tncData['Trip Total'].quantile(.5))
print('Total fare (fare + tip) 75th quantile:', tncData['Trip Total'].quantile(.75))
# Out:
# Average TNC trip total fare (fare + tip): 14.508187245439336
# Maximum TNC trip total fare (fare + tip): 1092.05
# Minimum TNC trip total fare (fare + tip): 0.0
# Total fare (fare + tip) 25th quantile: 7.5
# Total fare (fare + tip) 50th quantile: 10.0
# Total fare (fare + tip) 75th quantile: 17.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncData['Trip Total'], vert=False)
ax1.title.set_text('TNC Total Fare (fare + tip) Boxplot')

# %% [markdown]
# Removing top 2% of total fares

# %%
tncTotalFare98 = tncData[tncData['Trip Total'] <= tncData['Trip Total'].quantile(.98)]
tncAvgTripTotal = tncTotalFare98['Trip Total'].mean()
tncMaxTripTotal = tncTotalFare98['Trip Total'].max()
tncMinTripTotal = tncTotalFare98['Trip Total'].min()
print('Average TNC trip total fare (fare + tip):', tncAvgTripTotal)
print('Maximum TNC trip total fare (fare + tip):', tncMaxTripTotal)
print('Minimum TNC trip total fare (fare + tip):', tncMinTripTotal)
# Out:
# Average TNC trip total fare (fare + tip): 13.52810255224511
# Maximum TNC trip total fare (fare + tip): 48.25
# Minimum TNC trip total fare (fare + tip): 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncTotalFare98['Trip Total'], vert=False)
ax1.title.set_text('TNC Total Fare (fare + tip) (98th percentile) Boxplot')

# %% [markdown]
# **Trip Distance**

# %%
tncAvgDistance = tncData['Trip Miles'].mean()
tncMaxDistance = tncData['Trip Miles'].max()
tncMinDistance = tncData['Trip Miles'].min()
print('Average TNC distance (miles):', tncAvgDistance)
print('Maximum TNC distance (miles):', tncMaxDistance)
print('Minimum TNC distance (miles):', tncMinDistance)
print('Distance 25th quantile:', tncData['Trip Miles'].quantile(.25))
print('Distance 50th quantile:', tncData['Trip Miles'].quantile(.5))
print('Distance 75th quantile:', tncData['Trip Miles'].quantile(.75))
# Out:
# Average TNC distance (miles): 5.987792162160018
# Maximum TNC distance (miles): 389.9
# Minimum TNC distance (miles): 0.0
# Distance 25th quantile: 1.8
# Distance 50th quantile: 3.6
# Distance 75th quantile: 7.5

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncData['Trip Miles'], vert=False)
ax1.title.set_text('TNC Distance (Miles) Boxplot')

# %% [markdown]
# Removing top 2% of trip distances

# %%
tncDistance98 = tncData[tncData['Trip Miles'] <= tncData['Trip Miles'].quantile(.98)]
tncAvgDistance = tncDistance98['Trip Miles'].mean()
tncMaxDistance = tncDistance98['Trip Miles'].max()
tncMinDistance = tncDistance98['Trip Miles'].min()
print('Average TNC distance (miles):', tncAvgDistance)
print('Maximum TNC distance (miles):', tncMaxDistance)
print('Minimum TNC distance (miles):', tncMinDistance)
# Out:
# Average TNC distance (miles): 5.42744537885627
# Maximum TNC distance (miles): 25.6
# Minimum TNC distance (miles): 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncDistance98['Trip Miles'], vert=False)
ax1.title.set_text('TNC Distance (Miles) (98th percentile) Boxplot')

# %% [markdown]
# **Trip duration**

# %%
tncAvgDuration = tncData['Trip Seconds'].mean()
tncMaxDuration = tncData['Trip Seconds'].max()
tncMinDuration = tncData['Trip Seconds'].min()
print('Average TNC duration (seconds):', tncAvgDuration)
print('Maximum TNC duration (seconds):', tncMaxDuration)
print('Minimum TNC duration (seconds):', tncMinDuration)
print('Duration 25th quantile:', tncData['Trip Seconds'].quantile(.25))
print('Duration 50th quantile:', tncData['Trip Seconds'].quantile(.5))
print('Duration 75th quantile:', tncData['Trip Seconds'].quantile(.75))
# Out:
# Average TNC duration (seconds): 1099.0748530399162
# Maximum TNC duration (seconds): 67560.0
# Minimum TNC duration (seconds): 0.0
# Duration 25th quantile: 540.0
# Duration 50th quantile: 877.0
# Duration 75th quantile: 1425.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncData['Trip Seconds'], vert=False)
ax1.title.set_text('TNC Duration (Seconds) Boxplot')

# %% [markdown]
# Removing top 2% of durations

# %%
tncDuration98 = tncData[tncData['Trip Seconds'] <= tncData['Trip Seconds'].quantile(.98)]
tncAvgDuration = tncDuration98['Trip Seconds'].mean()
tncMaxDuration = tncDuration98['Trip Seconds'].max()
tncMinDuration = tncDuration98['Trip Seconds'].min()
print('Average TNC duration (seconds):', tncAvgDuration)
print('Maximum TNC duration (seconds):', tncMaxDuration)
print('Minimum TNC duration (seconds):', tncMinDuration)
# Out:
# Average TNC duration (seconds): 1037.9965501409552
# Maximum TNC duration (seconds): 3376.0
# Minimum TNC duration (seconds): 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(tncDuration98['Trip Seconds'], vert=False)
ax1.title.set_text('TNC Duration (Seconds) (98th percentile) Boxplot')

# %% [markdown]
# **Rides per day**

# %%
totalTNC_ridesPerDay = tncData.groupby(by=tncData['StartDateTime'].dt.date).count()['Trip ID']
print(totalTNC_ridesPerDay)
# Out:
# StartDateTime
# 2018-11-05    243582
# 2018-11-06    253651
# 2018-11-07    268917
# 2018-11-08    294292
# 2018-11-09    361842
# 2018-11-10    393377
# 2018-11-11    324546
# Name: Trip ID, dtype: int64

# %% [markdown]
# **Fare per day**

# %%
tncFarePerDay = tncData.groupby(by=tncData['StartDateTime'].dt.date).agg({'Fare': [np.mean, np.min, np.max]})
print(tncFarePerDay)
# Out:
#                     Fare
#                     mean amin    amax
# StartDateTime
# 2018-11-05     11.704210  0.0   377.5
# 2018-11-06     10.896862  0.0   452.5
# 2018-11-07     11.306425  0.0   400.0
# 2018-11-08     11.608360  0.0   325.0
# 2018-11-09     11.281250  0.0   447.5
# 2018-11-10     10.221187  0.0   682.5
# 2018-11-11     11.059226  0.0  1090.0

# %% [markdown]
# **Tip per day**

# %%
tncTipPerDay = tncData.groupby(by=tncData['StartDateTime'].dt.date).agg({'Tip': [np.mean, np.min, np.max]})
print(tncTipPerDay)
# Out:
#                     Tip
#                    mean amin amax
# StartDateTime
# 2018-11-05     0.548062    0   99
# 2018-11-06     0.511951    0  100
# 2018-11-07     0.566145    0   60
# 2018-11-08     0.598932    0   70
# 2018-11-09     0.561585    0   50
# 2018-11-10     0.504458    0   84
# 2018-11-11     0.578698    0  100

# %% [markdown]
# **Total fare (fare + tip) per day**

# %%
tncTripTotalPerDay = tncData.groupby(by=tncData['StartDateTime'].dt.date).agg({'Trip Total': [np.mean, np.min, np.max]})
print(tncTripTotalPerDay)
# Out:
#               Trip Total
#                     mean  amin     amax
# StartDateTime
# 2018-11-05     15.336143  0.67   412.50
# 2018-11-06     14.268547  0.67   456.50
# 2018-11-07     14.750004  0.67   408.50
# 2018-11-08     15.146948  0.67   328.40
# 2018-11-09     14.712904  0.67   459.35
# 2018-11-10     13.359742  0.00   696.40
# 2018-11-11     14.458259  0.67  1092.05

# %% [markdown]
# **Distance (miles) per day**

# %%
tncDistancePerDay = tncData.groupby(by=tncData['StartDateTime'].dt.date).agg({'Trip Miles': [np.mean, np.min, np.max]})
print(tncDistancePerDay)
# Out:
#               Trip Miles
#                     mean amin   amax
# StartDateTime
# 2018-11-05      6.601946  0.0  316.5
# 2018-11-06      6.055546  0.0  389.9
# 2018-11-07      6.178317  0.0  202.1
# 2018-11-08      6.207602  0.0  207.5
# 2018-11-09      5.811579  0.0  296.7
# 2018-11-10      5.332531  0.0  320.6
# 2018-11-11      6.107406  0.0  261.0

# %% [markdown]
# **Duration (seconds) per day**

# %%
tncDurationPerDay = tncData.groupby(by=tncData['StartDateTime'].dt.date).agg({'Trip Seconds': [np.mean, np.min, np.max]})
print(tncDurationPerDay)
# Out:
#               Trip Seconds
#                       mean amin     amax
# StartDateTime
# 2018-11-05     1159.344537  3.0  20948.0
# 2018-11-06     1114.189816  0.0  28704.0
# 2018-11-07     1152.315900  0.0  34877.0
# 2018-11-08     1188.777228  0.0  26760.0
# 2018-11-09     1150.038940  0.0  67560.0
# 2018-11-10      982.680975  0.0  17358.0
# 2018-11-11     1000.830160  0.0  26346.0

# %% [markdown]
# **Peak hour per day**

# %%
dateRange = pd.date_range(start='2018-11-05', end='2018-11-11')
for date in dateRange:
    tncTripsThisDay = tncData[(tncData['StartDateTime'] >= date) & (tncData['StartDateTime'] < (date + pd.DateOffset(1)))]
    tripsPerHour = tncTripsThisDay['Trip ID'].groupby(by=tncTripsThisDay['StartDateTime'].dt.hour).count()
    print('Peak hour for', date, 'is', tripsPerHour.idxmax(), 'with', tripsPerHour[tripsPerHour.idxmax()], 'trips.')
# Out:
# Peak hour for 2018-11-05 00:00:00 is 17 with 14965 trips.
# Peak hour for 2018-11-06 00:00:00 is 17 with 16668 trips.
# Peak hour for 2018-11-07 00:00:00 is 17 with 17425 trips.
# Peak hour for 2018-11-08 00:00:00 is 18 with 19135 trips.
# Peak hour for 2018-11-09 00:00:00 is 19 with 24030 trips.
# Peak hour for 2018-11-10 00:00:00 is 23 with 24810 trips.
# Peak hour for 2018-11-11 00:00:00 is 0 with 23157 trips.

# %% [markdown]
# ### Loading and exploring Taxi data

# %%
taxiData = pd.read_csv(inputDataPath + taxiInputFileName, delimiter=',', index_col=0)

# %%
taxiData.head()
# Out:
#                                          Trip ID  \
# 0       493d28d1aef5aaf0764ea3192d92090ac75121ed
# 305643  eb810f6b891baa03fe6684c798b5c8a1a9bda143
# 305644  3f205337b016faad57fe90288c05814bd5ecfac1
# 305645  d97eb24911ebd9a9a1bb7f1c771ad963a09256dd
# 305652  3c18e189acc6b1a86e143e5b97a6ee4ae6d8906b
#
#                                                   Taxi ID  \
# 0       ff214d6d48867d32b43c8caf27613acc83d3a03a290c37...
# 305643  8b518cb35743db24b2498b46d3eb2e89321a5f26a4601f...
# 305644  d38890256d8a1e8146f0b15dc23e3b2a140b4fa3834698...
# 305645  29f6d119e21d61401aa5156346aca14fad3d0fea0dc1c8...
# 305652  fdd5ae66de73dcf0baaf4a768c182b0c9e0579643672c0...
#
#           Trip Start Timestamp      Trip End Timestamp  Trip Seconds  \
# 0       11/08/2016 03:15:00 PM  10/11/2016 06:00:00 AM           NaN
# 305643  11/07/2016 12:00:00 AM  11/07/2016 12:00:00 AM           0.0
# 305644  11/07/2016 12:00:00 AM  11/07/2016 12:00:00 AM         180.0
# ...

# %%
taxiData.tail()
# Out:
#                                           Trip ID  \
# 1296063  62d526e28631c24e3c63a4cac32bc5068433a9f6
# 1296067  6f2c440efc684c18966fc8fa930ae2fa54b593da
# 1296070  559d7e545c8794dd75480c7c8838c5d7a91f40dd
# 1296076  5275a3e55cbb1c095c087a3cff5082dba462281c
# 1296082  4f3ee987e0f66e3fe7d257a4146a0123df773908
#
#                                                    Taxi ID  \
# 1296063  2a0dffcdb837d73460febb3e3882633bba0563b966825a...
# 1296067  2a0dffcdb837d73460febb3e3882633bba0563b966825a...
# 1296070  2a0dffcdb837d73460febb3e3882633bba0563b966825a...
# 1296076  2a0dffcdb837d73460febb3e3882633bba0563b966825a...
# 1296082  2a0dffcdb837d73460febb3e3882633bba0563b966825a...
#
#            Trip Start Timestamp Trip End Timestamp  Trip Seconds  Trip Miles  \
# 1296063  11/11/2016 10:00:00 AM                NaN           NaN         0.0
# 1296067  11/12/2016 03:00:00 PM                NaN           NaN         0.0
# ...

# %%
taxiData.shape
# Out:
# (321107, 23)

# %%
taxiData.dtypes
# Out:
# Trip ID                        object
# Taxi ID                        object
# Trip Start Timestamp           object
# Trip End Timestamp             object
# Trip Seconds                  float64
# Trip Miles                    float64
# Pickup Census Tract           float64
# Dropoff Census Tract          float64
# Pickup Community Area         float64
# Dropoff Community Area        float64
# Fare                          float64
# Tips                          float64
# Tolls                         float64
# Extras                        float64
# Trip Total                    float64
# Payment Type                   object
# Company                        object
# Pickup Centroid Latitude      float64
# Pickup Centroid Longitude     float64
# Pickup Centroid Location       object
# Dropoff Centroid Latitude     float64
# Dropoff Centroid Longitude    float64
# Dropoff Centroid  Location     object
# dtype: object

# %% [markdown]
# ### Creating new fields of type `datetime` for start and end times

# %%
# Transform fields to 'Datetime'
taxiData['StartDateTime'] = pd.to_datetime(taxiData['Trip Start Timestamp'])
taxiData['EndDateTime'] = pd.to_datetime(taxiData['Trip End Timestamp'])

# %%
taxiData.dtypes
# Out:
# Trip ID                               object
# Taxi ID                               object
# Trip Start Timestamp                  object
# Trip End Timestamp                    object
# Trip Seconds                         float64
# Trip Miles                           float64
# Pickup Census Tract                  float64
# Dropoff Census Tract                 float64
# Pickup Community Area                float64
# Dropoff Community Area               float64
# Fare                                 float64
# Tips                                 float64
# Tolls                                float64
# Extras                               float64
# Trip Total                           float64
# Payment Type                          object
# Company                               object
# Pickup Centroid Latitude             float64
# Pickup Centroid Longitude            float64
# Pickup Centroid Location              object
# Dropoff Centroid Latitude            float64
# ...

# %% [markdown]
# ### Removing invalid rows

# %%
cleanTaxiData = taxiData[taxiData['Fare'].isna() == False]
cleanTaxiData = cleanTaxiData[cleanTaxiData['Tips'].isna() == False]
cleanTaxiData = cleanTaxiData[cleanTaxiData['Trip Total'].isna() == False]
cleanTaxiData = cleanTaxiData[cleanTaxiData['Trip Miles'].isna() == False]
cleanTaxiData = cleanTaxiData[cleanTaxiData['Trip Seconds'].isna() == False]
print('Invalid rows:', taxiData.shape[0] - cleanTaxiData.shape[0])
# Out:
# Invalid rows: 55

# %% [markdown]
# ### Generating summary statistics for Taxi trips

# %%
totalTaxiRides = len(cleanTaxiData)
print('Total Taxi rides:', totalTaxiRides)
# Out:
# Total Taxi rides: 321052

# %% [markdown]
# **Fares**

# %%
taxiAvgFare = cleanTaxiData['Fare'].mean()
taxiMaxFare = cleanTaxiData['Fare'].max()
taxiMinFare = cleanTaxiData['Fare'].min()
print('Average Taxi fare:', taxiAvgFare)
print('Maximum Taxi fare:', taxiMaxFare)
print('Minimum Taxi fare:', taxiMinFare)
print('Fare 25th quantile:', cleanTaxiData['Fare'].quantile(.25))
print('Fare 50th quantile:', cleanTaxiData['Fare'].quantile(.5))
print('Fare 75th quantile:', cleanTaxiData['Fare'].quantile(.75))
# Out:
# Average Taxi fare: 14.374365429899205
# Maximum Taxi fare: 6666.66
# Minimum Taxi fare: 0.0
# Fare 25th quantile: 6.25
# Fare 50th quantile: 8.5
# Fare 75th quantile: 14.75

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(cleanTaxiData['Fare'], vert=False)
ax1.title.set_text('Taxi Fare Boxplot')

# %% [markdown]
# Removing top 2% fares

# %%
taxiFare98 = cleanTaxiData[cleanTaxiData['Fare'] <= cleanTaxiData['Fare'].quantile(.98)]
taxiAvgFare = taxiFare98['Fare'].mean()
taxiMaxFare = taxiFare98['Fare'].max()
taxiMinFare = taxiFare98['Fare'].min()
print('Average Taxi fare:', taxiAvgFare)
print('Maximum Taxi fare:', taxiMaxFare)
print('Minimum Taxi fare:', taxiMinFare)
# Out:
# Average Taxi fare: 13.339110413562382
# Maximum Taxi fare: 49.25
# Minimum Taxi fare: 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(taxiFare98['Fare'], vert=False)
ax1.title.set_text('Taxi Fare (98th percentile) Boxplot')

# %% [markdown]
# **Tips**

# %%
taxiAvgTip = cleanTaxiData['Tips'].mean()
taxiMaxTip = cleanTaxiData['Tips'].max()
taxiMinTip = cleanTaxiData['Tips'].min()
print('Average Taxi tip:', taxiAvgTip)
print('Maximum Taxi tip:', taxiMaxTip)
print('Minimum Taxi tip:', taxiMinTip)
print('Tips 25th quantile:', cleanTaxiData['Tips'].quantile(.25))
print('Tips 50th quantile:', cleanTaxiData['Tips'].quantile(.5))
print('Tips 75th quantile:', cleanTaxiData['Tips'].quantile(.75))
# Out:
# Average Taxi tip: 1.7900057000112133
# Maximum Taxi tip: 120.0
# Minimum Taxi tip: 0.0
# Tips 25th quantile: 0.0
# Tips 50th quantile: 0.0
# Tips 75th quantile: 2.15

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(cleanTaxiData['Tips'], vert=False)
ax1.title.set_text('Taxi Tip Boxplot')

# %% [markdown]
# Removing top 2% tips

# %%
taxiTips98 = cleanTaxiData[cleanTaxiData['Tips'] <= cleanTaxiData['Tips'].quantile(.98)]
taxiAvgTip = taxiTips98['Tips'].mean()
taxiMaxTip = taxiTips98['Tips'].max()
taxiMinTip = taxiTips98['Tips'].min()
print('Average Taxi tip:', taxiAvgTip)
print('Maximum Taxi tip:', taxiMaxTip)
print('Minimum Taxi tip:', taxiMinTip)
# Out:
# Average Taxi tip: 1.55603514669344
# Maximum Taxi tip: 10.55
# Minimum Taxi tip: 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(taxiTips98['Tips'], vert=False)
ax1.title.set_text('Taxi Tip (98th percentile) Boxplot')

# %% [markdown]
# **Total fare (fare + tip)**

# %%
taxiAvgTripTotal = cleanTaxiData['Trip Total'].mean()
taxiMaxTripTotal = cleanTaxiData['Trip Total'].max()
taxiMinTripTotal = cleanTaxiData['Trip Total'].min()
print('Average Taxi total fare (fare + tips):', taxiAvgTripTotal)
print('Maximum Taxi total fare (fare + tips):', taxiMaxTripTotal)
print('Minimum Taxi total fare (fare + tips):', taxiMinTripTotal)
print('Total fare 25th quantile:', cleanTaxiData['Trip Total'].quantile(.25))
print('Total fare 50th quantile:', cleanTaxiData['Trip Total'].quantile(.5))
print('Total fare 75th quantile:', cleanTaxiData['Trip Total'].quantile(.75))
# Out:
# Average Taxi total fare (fare + tips): 17.407524980377016
# Maximum Taxi total fare (fare + tips): 6666.66
# Minimum Taxi total fare (fare + tips): 0.0
# Total fare 25th quantile: 7.5
# Total fare 50th quantile: 10.25
# Total fare 75th quantile: 17.2

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(cleanTaxiData['Trip Total'], vert=False)
ax1.title.set_text('Taxi Total Fare (fare + tip) Boxplot')

# %% [markdown]
# Removing top 2% total fares

# %%
taxiTotal98 = cleanTaxiData[cleanTaxiData['Trip Total'] <= cleanTaxiData['Trip Total'].quantile(.98)]
taxiAvgTripTotal = taxiTotal98['Trip Total'].mean()
taxiMaxTripTotal = taxiTotal98['Trip Total'].max()
taxiMinTripTotal = taxiTotal98['Trip Total'].min()
print('Average Taxi total fare (fare + tips):', taxiAvgTripTotal)
print('Maximum Taxi total fare (fare + tips):', taxiMaxTripTotal)
print('Minimum Taxi total fare (fare + tips):', taxiMinTripTotal)
# Out:
# Average Taxi total fare (fare + tips): 15.97925303700973
# Maximum Taxi total fare (fare + tips): 62.7
# Minimum Taxi total fare (fare + tips): 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(taxiTotal98['Trip Total'], vert=False)
ax1.title.set_text('Taxi Total Fare (fare + tip) (98th percentile) Boxplot')

# %% [markdown]
# **Distance**

# %%
taxiAvgDistance = cleanTaxiData['Trip Miles'].mean()
taxiMaxDistance = cleanTaxiData['Trip Miles'].max()
taxiMinDistance = cleanTaxiData['Trip Miles'].min()
print('Average Taxi distance (miles):', taxiAvgDistance)
print('Maximum Taxi distance (miles):', taxiMaxDistance)
print('Minimum Taxi distance (miles):', taxiMinDistance)
print('Total distance 25th quantile:', cleanTaxiData['Trip Miles'].quantile(.25))
print('Total distance 50th quantile:', cleanTaxiData['Trip Miles'].quantile(.5))
print('Total distance 75th quantile:', cleanTaxiData['Trip Miles'].quantile(.75))
# Out:
# Average Taxi distance (miles): 3.374867280066781
# Maximum Taxi distance (miles): 460.7
# Minimum Taxi distance (miles): 0.0
# Total distance 25th quantile: 0.4
# Total distance 50th quantile: 1.2
# Total distance 75th quantile: 3.1

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(cleanTaxiData['Trip Miles'], vert=False)
ax1.title.set_text('Taxi Distance (miles) Boxplot')

# %%
taxiDistance98 = cleanTaxiData[cleanTaxiData['Trip Miles'] <= cleanTaxiData['Trip Miles'].quantile(.98)]
taxiAvgDistance = taxiDistance98['Trip Miles'].mean()
taxiMaxDistance = taxiDistance98['Trip Miles'].max()
taxiMinDistance = taxiDistance98['Trip Miles'].min()
print('Average Taxi distance (miles):', taxiAvgDistance)
print('Maximum Taxi distance (miles):', taxiMaxDistance)
print('Minimum Taxi distance (miles):', taxiMinDistance)
# Out:
# Average Taxi distance (miles): 2.988601014705929
# Maximum Taxi distance (miles): 18.4
# Minimum Taxi distance (miles): 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(taxiDistance98['Trip Miles'], vert=False)
ax1.title.set_text('Taxi Distance (miles) (98th percentile) Boxplot')

# %% [markdown]
# **Duration (seconds)**

# %%
taxiAvgDuration = cleanTaxiData['Trip Seconds'].mean()
taxiMaxDuration = cleanTaxiData['Trip Seconds'].max()
taxiMinDuration = cleanTaxiData['Trip Seconds'].min()
print('Average Taxi duration (seconds):', taxiAvgDuration)
print('Maximum Taxi duration (seconds):', taxiMaxDuration)
print('Minimum Taxi duration (seconds):', taxiMinDuration)
print('Total Seconds 25th quantile:', cleanTaxiData['Trip Seconds'].quantile(.25))
print('Total Seconds 50th quantile:', cleanTaxiData['Trip Seconds'].quantile(.5))
print('Total Seconds 75th quantile:', cleanTaxiData['Trip Seconds'].quantile(.75))
# Out:
# Average Taxi duration (seconds): 870.3576149657999
# Maximum Taxi duration (seconds): 86392.0
# Minimum Taxi duration (seconds): 0.0
# Total Seconds 25th quantile: 360.0
# Total Seconds 50th quantile: 600.0
# Total Seconds 75th quantile: 1020.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(cleanTaxiData['Trip Seconds'], vert=False)
ax1.title.set_text('Taxi Duration (seconds) Boxplot')

# %% [markdown]
# Removing top 2% durations

# %%
taxiDuration98 = cleanTaxiData[cleanTaxiData['Trip Seconds'] <= cleanTaxiData['Trip Seconds'].quantile(.98)]
taxiAvgDuration = taxiDuration98['Trip Seconds'].mean()
taxiMaxDuration = taxiDuration98['Trip Seconds'].max()
taxiMinDuration = taxiDuration98['Trip Seconds'].min()
print('Average Taxi duration (seconds):', taxiAvgDuration)
print('Maximum Taxi duration (seconds):', taxiMaxDuration)
print('Minimum Taxi duration (seconds):', taxiMinDuration)
# Out:
# Average Taxi duration (seconds): 782.7358021476971
# Maximum Taxi duration (seconds): 3480.0
# Minimum Taxi duration (seconds): 0.0

# %%
plt.rcParams["figure.figsize"] = [20,4]
fig1, ax1 = plt.subplots()
ax1.boxplot(taxiDuration98['Trip Seconds'], vert=False)
ax1.title.set_text('Taxi Duration (seconds) (98th percentile) Boxplot')

# %% [markdown]
# **Taxi rides per day**

# %%
totalTaxi_ridesPerDay = cleanTaxiData.groupby(by=cleanTaxiData['StartDateTime'].dt.date).count()['Trip ID']
print(totalTaxi_ridesPerDay)
# Out:
# StartDateTime
# 2016-11-07    47153
# 2016-11-08    48582
# 2016-11-09    50928
# 2016-11-10    51004
# 2016-11-11    50178
# 2016-11-12    40029
# 2016-11-13    33178
# Name: Trip ID, dtype: int64

# %% [markdown]
# **Taxi fares per day**

# %%
taxiFarePerDay = cleanTaxiData.groupby(by=cleanTaxiData['StartDateTime'].dt.date).agg({'Fare': [np.mean, np.min, np.max]})
print(taxiFarePerDay)
# Out:
#                     Fare
#                     mean amin     amax
# StartDateTime
# 2016-11-07     14.681802  0.0   600.00
# 2016-11-08     13.989353  0.0   884.48
# 2016-11-09     15.324855  0.0  1025.11
# 2016-11-10     14.718644  0.0  6666.66
# 2016-11-11     13.975399  0.0  5135.25
# 2016-11-12     12.258163  0.0   999.99
# 2016-11-13     15.669526  0.0   999.99

# %% [markdown]
# **Taxi tips per day**

# %%
taxiTipPerDay = cleanTaxiData.groupby(by=cleanTaxiData['StartDateTime'].dt.date).agg({'Tips': [np.mean, np.min, np.max]})
print(taxiTipPerDay)
# Out:
#                    Tips
#                    mean amin   amax
# StartDateTime
# 2016-11-07     1.858267  0.0  100.0
# 2016-11-08     1.859358  0.0  120.0
# 2016-11-09     2.089366  0.0   75.0
# 2016-11-10     1.914874  0.0  100.0
# 2016-11-11     1.700375  0.0  120.0
# 2016-11-12     1.204620  0.0   50.0
# 2016-11-13     1.781788  0.0   70.0

# %% [markdown]
# **Taxi total fare (fare + tip) per day**

# %%
taxiTripTotalPerDay = cleanTaxiData.groupby(by=cleanTaxiData['StartDateTime'].dt.date).agg({'Trip Total': [np.mean, np.min, np.max]})
print(taxiTripTotalPerDay)
# Out:
#               Trip Total
#                     mean amin     amax
# StartDateTime
# 2016-11-07     17.859261  0.0  3010.00
# 2016-11-08     17.022674  0.0  4114.39
# 2016-11-09     18.590947  0.0  1558.75
# 2016-11-10     17.723097  0.0  6666.66
# 2016-11-11     16.903539  0.0  5145.82
# 2016-11-12     14.573973  0.0   999.99
# 2016-11-13     19.208254  0.0  3341.83

# %% [markdown]
# **Taxi distance (miles) per day**

# %%
taxiDistancePerDay = cleanTaxiData.groupby(by=cleanTaxiData['StartDateTime'].dt.date).agg({'Trip Miles': [np.mean, np.min, np.max]})
print(taxiDistancePerDay)
# Out:
#               Trip Miles
#                     mean amin   amax
# StartDateTime
# 2016-11-07      3.508700  0.0  455.2
# 2016-11-08      3.273653  0.0  363.9
# 2016-11-09      3.669138  0.0  270.0
# 2016-11-10      3.389545  0.0  251.1
# 2016-11-11      3.248612  0.0  100.0
# 2016-11-12      2.672656  0.0  460.7
# 2016-11-13      3.896761  0.0   87.1

# %% [markdown]
# **Taxi duration (seconds) per day**

# %%
taxiDurationPerDay = cleanTaxiData.groupby(by=cleanTaxiData['StartDateTime'].dt.date).agg({'Trip Seconds': [np.mean, np.min, np.max]})
print(taxiDurationPerDay)
# Out:
#               Trip Seconds
#                       mean amin     amax
# StartDateTime
# 2016-11-07      892.384366  0.0  86375.0
# 2016-11-08      854.766374  0.0  86392.0
# 2016-11-09      972.993245  0.0  86384.0
# 2016-11-10      933.555800  0.0  86387.0
# 2016-11-11      851.388118  0.0  86384.0
# 2016-11-12      731.294836  0.0  86385.0
# 2016-11-13      803.651787  0.0  83040.0

# %% [markdown]
# **Taxi peak hour per day**

# %%
dateRange = pd.date_range(start='2016-11-07', end='2016-11-13')
for date in dateRange:
    taxiTripsThisDay = cleanTaxiData[(taxiData['StartDateTime'] >= date) & (cleanTaxiData['StartDateTime'] < (date + pd.DateOffset(1)))]
    tripsPerHour = taxiTripsThisDay['Trip ID'].groupby(by=taxiTripsThisDay['StartDateTime'].dt.hour).count()
    print('Peak hour for', date, 'is', tripsPerHour.idxmax(), 'with', tripsPerHour[tripsPerHour.idxmax()], 'trips.')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Peak hour for 2016-11-07 00:00:00 is 18 with 3562 trips.
# Peak hour for 2016-11-08 00:00:00 is 18 with 3477 trips.
# Peak hour for 2016-11-09 00:00:00 is 18 with 3233 trips.
# Peak hour for 2016-11-10 00:00:00 is 18 with 3643 trips.
# Peak hour for 2016-11-11 00:00:00 is 18 with 3670 trips.
# Peak hour for 2016-11-12 00:00:00 is 19 with 2831 trips.
# Peak hour for 2016-11-13 00:00:00 is 0 with 2659 trips.

# %% [markdown]
# ### Generating weekly and daily graphs for each dataset and combined

# %%
tncTripsByHour = tncData.resample('H', on='StartDateTime').count()
plt.rcParams["figure.figsize"] = [20,10]
fig = plt.figure()
ax = plt.axes()
ax.xaxis.grid(linestyle=':')
plt.ylabel('Number of TNC trips')
plt.title('Number of TNC trips per hour (Nov 5 - Nov 11, 2018)')
ax.plot(tncTripsByHour['Trip ID'], color='black')

# %%
taxiTripsByHour = cleanTaxiData.resample('H', on='StartDateTime').count()
plt.rcParams["figure.figsize"] = [20,10]
fig = plt.figure()
ax = plt.axes()
ax.xaxis.grid(linestyle=':')
plt.ylabel('Number of Taxi trips')
plt.title('Number of Taxi trips per hour (Nov 7 - Nov 13, 2016)')
ax.plot(taxiTripsByHour['Trip ID'], color='black')

# %%
hourlyTNC = tncTripsByHour.reset_index(drop=True)
hourlyTaxi = taxiTripsByHour.reset_index(drop=True)
fig = plt.figure()
ax = plt.axes()
ax.xaxis.grid(linestyle=':')
plt.ylabel('Number of trips')
plt.title('Number of TNC and Taxi trips per hour for selected weeks')
ax.plot(hourlyTNC['Trip ID'], color='black', label='TNC trips')
ax.plot(hourlyTaxi['Trip ID'], color='red', label='Taxi trips')
ax.legend()

# %% [markdown]
# ### Exporting files with `datetime` fields

# %%
tncData.to_csv(outputDataPath + tncOutputFileName)
cleanTaxiData.to_csv(outputDataPath + taxiOutputFileName)
